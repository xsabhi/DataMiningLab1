# %% [markdown]
# # Purpose of Dataset Selected

# %% [markdown]
# The purpose of our project is to determine the reliability of an airline based on their prior on-time statistics spanning data for one year.
#
# The following dataset is downloaded from the bureau of transportation website and contains metrics for domestic flights by major carriers.  It contains on-time arrival data such as departure and arrival delays, origin and destination airports, flight numbers, scheduled and actual departure and arrival times, cancelled or diverted flights, taxi-out and taxi-in times, air time, and non-stop distance.
#
# For the purpose of this study, we downloaded data spanning February 2016 to February 2017.  There are 6,032,365 total records and 109 attributes.

# %% [markdown]
# # Data Meaning Type

# %%
import pandas as pd
pd.read_clipboard()
# Out:
#              Field Name                                  Field Description  \
# 0                  Year                                               Year
# 1               Quarter                                      Quarter (1-4)
# 2                 Month                                              Month
# 3            DayofMonth                                       Day of Month
# 4             DayOfWeek                                        Day of Week
# 5            FlightDate                             Flight Date (yyyymmdd)
# 6         UniqueCarrier  Unique Carrier Code. When the same code has be...
# 7             AirlineID  An identification number assigned by US DOT to...
# 8               Carrier  Code assigned by IATA and commonly used to ide...
# 9               TailNum                                        Tail Number
# 10            FlightNum                                      Flight Number
# 11      OriginAirportID  Origin Airport, Airport ID. An identification ...
# 12   OriginAirportSeqID  Origin Airport, Airport Sequence ID. An identi...
# 13   OriginCityMarketID  Origin Airport, City Market ID. City Market ID...
# 14               Origin                                     Origin Airport
# 15       OriginCityName                          Origin Airport, City Name
# 16          OriginState                         Origin Airport, State Code
# 17      OriginStateFips                         Origin Airport, State Fips
# 18      OriginStateName                         Origin Airport, State Name
# 19            OriginWac                    Origin Airport, World Area Code
# 20        DestAirportID  Destination Airport, Airport ID. An identifica...
# 21     DestAirportSeqID  Destination Airport, Airport Sequence ID. An i...
# 22     DestCityMarketID  Destination Airport, City Market ID. City Mark...
# 23                 Dest                                Destination Airport
# 24         DestCityName                     Destination Airport, City Name
# 25            DestState                    Destination Airport, State Code
# 26        DestStateFips                    Destination Airport, State Fips
# 27        DestStateName                    Destination Airport, State Name
# 28              DestWac               Destination Airport, World Area Code
# 29           CRSDepTime              CRS Departure Time (local time: hhmm)
# ..                  ...                                                ...
# 79     Div2AirportSeqID  Airport Sequence ID of Diverted Airport 2. Uni...
# 80         Div2WheelsOn  Wheels On Time (local time: hhmm) at Diverted ...
# 81       Div2TotalGTime  Total Ground Time Away from Gate at Diverted A...
# 82     Div2LongestGTime  Longest Ground Time Away from Gate at Diverted...
# 83        Div2WheelsOff  Wheels Off Time (local time: hhmm) at Diverted...
# 84          Div2TailNum    Aircraft Tail Number for Diverted Airport Code2
# 85          Div3Airport                             Diverted Airport Code3
# 86        Div3AirportID  Airport ID of Diverted Airport 3. Airport ID i...
# 87     Div3AirportSeqID  Airport Sequence ID of Diverted Airport 3. Uni...
# 88         Div3WheelsOn  Wheels On Time (local time: hhmm) at Diverted ...
# 89       Div3TotalGTime  Total Ground Time Away from Gate at Diverted A...
# 90     Div3LongestGTime  Longest Ground Time Away from Gate at Diverted...
# 91        Div3WheelsOff  Wheels Off Time (local time: hhmm) at Diverted...
# 92          Div3TailNum    Aircraft Tail Number for Diverted Airport Code3
# 93          Div4Airport                             Diverted Airport Code4
# 94        Div4AirportID  Airport ID of Diverted Airport 4. Airport ID i...
# 95     Div4AirportSeqID  Airport Sequence ID of Diverted Airport 4. Uni...
# 96         Div4WheelsOn  Wheels On Time (local time: hhmm) at Diverted ...
# 97       Div4TotalGTime  Total Ground Time Away from Gate at Diverted A...
# 98     Div4LongestGTime  Longest Ground Time Away from Gate at Diverted...
# 99        Div4WheelsOff  Wheels Off Time (local time: hhmm) at Diverted...
# 100         Div4TailNum    Aircraft Tail Number for Diverted Airport Code4
# 101         Div5Airport                             Diverted Airport Code5
# 102       Div5AirportID  Airport ID of Diverted Airport 5. Airport ID i...
# 103    Div5AirportSeqID  Airport Sequence ID of Diverted Airport 5. Uni...
# 104        Div5WheelsOn  Wheels On Time (local time: hhmm) at Diverted ...
# 105      Div5TotalGTime  Total Ground Time Away from Gate at Diverted A...
# 106    Div5LongestGTime  Longest Ground Time Away from Gate at Diverted...
# 107       Div5WheelsOff  Wheels Off Time (local time: hhmm) at Diverted...
# 108         Div5TailNum    Aircraft Tail Number for Diverted Airport Code5
#
#      Data Type  % Missing
# 0          NaN        NaN
# 1          NaN        NaN
# 2          NaN        NaN
# 3          NaN        NaN
# 4          NaN        NaN
# 5          NaN        NaN
# 6          NaN        NaN
# 7          NaN        NaN
# 8          NaN        NaN
# 9          NaN        NaN
# 10         NaN        NaN
# 11         NaN        NaN
# 12         NaN        NaN
# 13         NaN        NaN
# 14         NaN        NaN
# 15         NaN        NaN
# 16         NaN        NaN
# 17         NaN        NaN
# 18         NaN        NaN
# 19         NaN        NaN
# 20         NaN        NaN
# 21         NaN        NaN
# 22         NaN        NaN
# 23         NaN        NaN
# 24         NaN        NaN
# 25         NaN        NaN
# 26         NaN        NaN
# 27         NaN        NaN
# 28         NaN        NaN
# 29         NaN        NaN
# ..         ...        ...
# 79         NaN        NaN
# 80         NaN        NaN
# 81         NaN        NaN
# 82         NaN        NaN
# 83         NaN        NaN
# 84         NaN        NaN
# 85         NaN        NaN
# 86         NaN        NaN
# 87         NaN        NaN
# 88         NaN        NaN
# 89         NaN        NaN
# 90         NaN        NaN
# 91         NaN        NaN
# 92         NaN        NaN
# 93         NaN        NaN
# 94         NaN        NaN
# 95         NaN        NaN
# 96         NaN        NaN
# 97         NaN        NaN
# 98         NaN        NaN
# 99         NaN        NaN
# 100        NaN        NaN
# 101        NaN        NaN
# 102        NaN        NaN
# 103        NaN        NaN
# 104        NaN        NaN
# 105        NaN        NaN
# 106        NaN        NaN
# 107        NaN        NaN
# 108        NaN        NaN
#
# [109 rows x 4 columns]

# %% [markdown]
# # Data Quality
